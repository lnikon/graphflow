# %%
import networkx as nx
from networkx.algorithms import community, bipartite
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
knodel_edgelist_path = '../build/exported-knodel-edges-after-push.txt'

# %%
# G = nx.read_edgelist(knodel_edgelist_path)
G = nx.Graph()
G.add_nodes_from(list(range(0, 4)), bipartite=0)
G.add_nodes_from(list(range(4, 8)), bipartite=1)
G = nx.read_edgelist(knodel_edgelist_path)

# %%
nx.is_bipartite(G)
# Out:
# True

# %%
bottom_nodes, top_nodes = bipartite.sets(G)
#top_nodes = [4, 5, 6, 7]

# %%
fig = plt.figure(figsize=(6,6))
pos = nx.bipartite_layout(G, top_nodes)
nx.draw(G, pos=pos, with_labels=True)

# %%
nx.is_bipartite(G)
bottom_nodes, top_nodes = bipartite.sets(G)
#top_nodes = [4, 5, 6, 7]
fig = plt.figure(figsize=(6,6))
pos = nx.bipartite_layout(G, top_nodes)
nx.draw(G, pos=pos, with_labels=True)

# %%
nx.is_bipartite(G)
bottom_nodes, top_nodes = bipartite.sets(G)
#top_nodes = [4, 5, 6, 7]
fig = plt.figure(figsize=(6,6))
pos = nx.bipartite_layout(G, top_nodes)
nx.draw(G, pos=pos, with_labels=True)
